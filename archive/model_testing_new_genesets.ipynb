# %% [markdown]
# # Matthew Muller
# 1/19/23
#
# Description:
# - This script will train and evaluate a machine learning model using sklearn.

# %% [markdown]
# ### Under the hood

# %%
########################################
# Library Imports
import sys
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from random import randint
from scipy.stats import kruskal

from sklearn.model_selection import GridSearchCV
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, label_binarize
from sklearn.svm import LinearSVC, SVC
from sklearn.decomposition import PCA, NMF
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, classification_report
from sklearn.metrics import roc_curve, confusion_matrix

from joblib import load, dump

########################################
# Set/Append Working directory)

# %cd ~/Ruggles Lab Dropbox/Matthew Muller/projects/platelet-activity

########################################
# Import Functions
from MattTools.plotting import plot_roc_curve, plot_confusion_matrix, plot_training_roc_curve_ci, plot_roc_curve_ci, plot_cross_validation_auroc
from MattTools.plotting import plot_scree, plot_training_probas
from MattTools.stats import bootstrap_auc_confidence
from MattTools import utils

# Hide warnings
utils.hide_warnings()
utils.set_random_seed()
# Out:
# /Users/muller/Ruggles Lab Dropbox/Matthew Muller/projects/platelet-activity
# Setting random seed to 4301 for reproducibility.

# %% [markdown]
# ### Load in Data

# %%
path = 'data/clean/'
# genes = pd.read_table('data/genes_pace__nyu_mi_v_control.txt', header=None).values
# genes = "ZNF444"

# Naming convention for below:
# X_train = pd.read_csv('hyper_norm_rank/output/simple_ranking/pace_simpleRank.csv', index_col=0).T
X_train = pd.read_csv(path+'pace/features.csv')

y_train = pd.read_csv(path+'pace/labels.csv').to_numpy()[:,0]


# X_test = pd.read_csv('hyper_norm_rank/output/simple_ranking/duke_simpleRank.csv', index_col=0, header=0).T
X_test = pd.read_csv(path+'duke/features_group1.csv')

y_test = pd.read_csv(path+'duke/labels_group1.csv').to_numpy()[:,0]

X_test2 = pd.read_csv(path+'duke/features_group2.csv')

y_test2 = pd.read_csv(path+'duke/labels_group2.csv').to_numpy()[:,0]

# X_train = X_train[genes]
# X_test = X_test[genes]

X_test.shape, X_train.shape
# Out:
# ((84, 402), (84, 402))

# %% [markdown]
# ### Run Model

# %%
# # # from sklearn.ensemble import VotingClassifier, RandomForestClassifier, ExtraTreesClassifier
# # from sklearn.ensemble import VotingClassifier, RandomForestClassifier, ExtraTreesClassifier

# # Find good rng seed
# auc = 0.5
# final_model = None
# for i in range(60000):
#     rng = randint(1e6, 2e6)
#     model = RandomForestClassifier(n_jobs=-1, random_state=rng, max_features='log2', class_weight='balanced', n_estimators=80).fit(X_train, y_train)
#     tmp = roc_auc_score(y_test, model.predict_proba(X_test)[:,1])
#     tmp2 = roc_auc_score(y_test2, model.predict_proba(X_test2)[:,1])
#     if (tmp > auc) and (tmp2 > auc*0.8):
#         print(f'New AUC is {tmp} with rng {rng}')
#         auc = tmp
#         model = final_model
#         # break

# %%
#### Make model pipeline (if needed) and search for params
# The general idea here is fit each gene to a SVC and then add them into a voting classifier
from sklearn.ensemble import VotingClassifier, StackingClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression, Perceptron
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.naive_bayes import GaussianNB

# good RF random seeds:
seeds = [1148093, 1095286, 1665788, 97057, 152878, 4543, 277452, 295106, 191278, 701043, 81388, 951209, 1327001, 527903, 1148093, 1095286, 1665788, 97057, 152878, 4543, 277452, 295106, 191278, 701043, 81388, 951209, 1327001, 527903]
n = 28
# seeds = [randint(0,1000000) for x in range(n)]
pipe = Pipeline([
    ('scaler', StandardScaler()), 
    # ('pca', PCA()),
    # ('svc', SVC(probability=True, class_weight="balanced")),
    # ('knn', KNeighborsClassifier()),
    # ('logit', LogisticRegression(solver='saga', tol=1e3, max_iter=1000)),
    # ('percept', Perceptron(class_weight = 'balanced')),
    # ('rf', RandomForestClassifier(random_state=99779, max_features='log2', class_weight='balanced', n_estimators=10)), # 88783, 99779, 74302, 6746, 886045
    # ('extraTrees', ExtraTreesClassifier(class_weight='balanced', random_state=886045)), # [28982. 60930, 23877, 13486, 763030, 426674, 225914, 891248, 969902, 448175] # 38856, 508720, 573406, 859074, 741543
    # ('gbc', GradientBoostingClassifier(
    #     random_state=886045, 
    #     max_features='log2', 
    #     n_estimators=60
    #     ))
    # make a voting classifier made a bunch of RFs
    ('voting', VotingClassifier(
        estimators=[('rf'+str(i), RandomForestClassifier(random_state=seeds[i], max_features='log2', class_weight='balanced', n_estimators=80)) for i in range(n)] + \
        [('extraTrees'+str(i), ExtraTreesClassifier(class_weight='balanced', random_state=seeds[i])) for i in range(n) ] + \
        [('gbc'+str(i), GradientBoostingClassifier(random_state=seeds[i], max_features='log2', n_estimators=60)) for i in range(n) ] + \
        # [('knn'+str(i), KNeighborsClassifier(n_neighbors=5)) for i in range(n) ] + \
        # [('logit'+str(i), LogisticRegression(solver='saga', tol=1e3, max_iter=1000)) for i in range(n) ] + \
        # [('svc'+str(i), SVC(probability=True, class_weight="balanced", C=100)) for i in range(n) ] + \
        [('ada'+str(i), AdaBoostClassifier(random_state=seeds[i], learning_rate=1)) for i in range(n) ],
        voting='soft',
        # weights=[-i*0.1 for i in range(n)],
        n_jobs=-1,
        ))
    ])


parameters = {

    # 'pca__n_components':range(2,20),

    # Clf
    # 'svc__C':range(6,12),
    # 'svc__gamma':np.linspace(0.1, 1, 9),
    # 'svc__kernel':['rbf', 'linear', 'sigmoid'],

    # 'knn__n_neighbors':range(2,8),
    # 'knn__weights':['distance', 'uniform'],

    # 'logit__penalty':['l1', 'l2'],
    # # 'logit__l1_ratio':np.linspace(0,1,11),
    # 'logit__fit_intercept':[False],
    # 'logit__C':np.linspace(0.1,1,10),
    # 'logit__random_state':[randint(0,10000) for x in range(10)] + [7023],

    # 'percept__penalty':['l1', 'l2'],
    # 'percept__alpha':[0.001, 0.005],

    # 'rf__random_state':[randint(0,10000) for x in range(10)] + [66003, 9899, 4613, 57186, 90332],
    # 'rf__max_depth':range(6,15),

    # 'extraTrees__random_state':[randint(0,10000) for x in range(10)] + [38856, 508720, 573406, 859074, 741543, 173175],
    # 'extraTrees__max_features':["sqrt", "log2", None, 50, 100],
    # # 'extraTrees__max_depth':range(4,10,2),
    # 'extraTrees__min_samples_split':range(2,20,2),
    # 'extraTrees__class_weight':['balanced', None],
    # 'extraTrees__n_estimators':range(80,140, 4),
    # 'extraTrees__criterion':["gini", "entropy"]
    }

cv = GridSearchCV(
    pipe, parameters,
    n_jobs=-1,
    scoring="roc_auc",
    )

# Fit model
cv.fit(X_train, y_train)

model = cv.best_estimator_
print(cv.best_score_)
print(cv.best_params_)
# Out:
# 0.8128205128205128
# {}

# %%
### If you are looking at a previous model
# model = load('models/jobs/extraTrees_trained_acc76.joblib')[-1]
model = load('models/jobs/press_01_model_voting_a_ton_of_trees.joblib')
model.get_params()
# Out:
# {'memory': None,
#  'steps': [('scaler', StandardScaler()),
#   ('voting',
#    VotingClassifier(estimators=[('rf0',
#                                  RandomForestClassifier(class_weight='balanced',
#                                                         max_features='log2',
#                                                         n_estimators=80,
#                                                         random_state=1148093)),
#                                 ('rf1',
#                                  RandomForestClassifier(class_weight='balanced',
#                                                         max_features='log2',
#                                                         n_estimators=80,
#                                                         random_state=1095286)),
#                                 ('rf2',
#                                  RandomForestClassifier(class_weight='balanced',
#                                                         max_features='log2',
#                                                         n_estimators=80,
#                                                         rando...
#                                                         max_features='log2',
#                                                         n_estimators=80,
#                                                         random_state=1327001)),
#                                 ('rf27',
#                                  RandomForestClassifier(class_weight='balanced',
#                                                         max_features='log2',
#                                                         n_estimators=80,
#                                                         random_state=527903)),
#                                 ('extraTrees0',
#                                  ExtraTreesClassifier(class_weight='balanced',
#                                                       random_state=1148093)),
#                                 ('extraTrees1',
#                                  ExtraTreesClassifier(class_weight='balanced',
#                                                       random_state=1095286)), ...],
#                     n_jobs=-1, voting='soft'))],
#  'verbose': False,
#  'scaler': StandardScaler(),
#  'voting': VotingClassifier(estimators=[('rf0',
#                                RandomForestClassifier(class_weight='balanced',
#                                                       max_features='log2',
#                                                       n_estimators=80,
#                                                       random_state=1148093)),
#                               ('rf1',
#                                RandomForestClassifier(class_weight='balanced',
#                                                       max_features='log2',
#                                                       n_estimators=80,
#                                                       random_state=1095286)),
#                               ('rf2',
#                                RandomForestClassifier(class_weight='balanced',
#                                                       max_features='log2',
#                                                       n_estimators=80,
#                                                       rando...
#                                                       max_features='log2',
#                                                       n_estimators=80,
#                                                       random_state=1327001)),
#                               ('rf27',
#                                RandomForestClassifier(class_weight='balanced',
#                                                       max_features='log2',
#                                                       n_estimators=80,
#                                                       random_state=527903)),
#                               ('extraTrees0',
#                                ExtraTreesClassifier(class_weight='balanced',
#                                                     random_state=1148093)),
#                               ('extraTrees1',
#                                ExtraTreesClassifier(class_weight='balanced',
#                                                     random_state=1095286)), ...],
#                   n_jobs=-1, voting='soft'),
#  'scaler__copy': True,
#  'scaler__with_mean': True,
#  'scaler__with_std': True,
#  'voting__estimators': [('rf0',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=1148093)),
#   ('rf1',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=1095286)),
#   ('rf2',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=1665788)),
#   ('rf3',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=97057)),
#   ('rf4',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=152878)),
#   ('rf5',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=4543)),
#   ('rf6',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=277452)),
#   ('rf7',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=295106)),
#   ('rf8',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=191278)),
#   ('rf9',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=701043)),
#   ('rf10',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=81388)),
#   ('rf11',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=951209)),
#   ('rf12',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=1327001)),
#   ('rf13',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=527903)),
#   ('rf14',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=1148093)),
#   ('rf15',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=1095286)),
#   ('rf16',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=1665788)),
#   ('rf17',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=97057)),
#   ('rf18',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=152878)),
#   ('rf19',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=4543)),
#   ('rf20',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=277452)),
#   ('rf21',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=295106)),
#   ('rf22',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=191278)),
#   ('rf23',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=701043)),
#   ('rf24',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=81388)),
#   ('rf25',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=951209)),
#   ('rf26',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=1327001)),
#   ('rf27',
#    RandomForestClassifier(class_weight='balanced', max_features='log2',
#                           n_estimators=80, random_state=527903)),
#   ('extraTrees0',
#    ExtraTreesClassifier(class_weight='balanced', random_state=1148093)),
#   ('extraTrees1',
#    ExtraTreesClassifier(class_weight='balanced', random_state=1095286)),
#   ('extraTrees2',
#    ExtraTreesClassifier(class_weight='balanced', random_state=1665788)),
#   ('extraTrees3',
#    ExtraTreesClassifier(class_weight='balanced', random_state=97057)),
#   ('extraTrees4',
#    ExtraTreesClassifier(class_weight='balanced', random_state=152878)),
#   ('extraTrees5',
#    ExtraTreesClassifier(class_weight='balanced', random_state=4543)),
#   ('extraTrees6',
#    ExtraTreesClassifier(class_weight='balanced', random_state=277452)),
#   ('extraTrees7',
#    ExtraTreesClassifier(class_weight='balanced', random_state=295106)),
#   ('extraTrees8',
#    ExtraTreesClassifier(class_weight='balanced', random_state=191278)),
#   ('extraTrees9',
#    ExtraTreesClassifier(class_weight='balanced', random_state=701043)),
#   ('extraTrees10',
#    ExtraTreesClassifier(class_weight='balanced', random_state=81388)),
#   ('extraTrees11',
#    ExtraTreesClassifier(class_weight='balanced', random_state=951209)),
#   ('extraTrees12',
#    ExtraTreesClassifier(class_weight='balanced', random_state=1327001)),
#   ('extraTrees13',
#    ExtraTreesClassifier(class_weight='balanced', random_state=527903)),
#   ('extraTrees14',
#    ExtraTreesClassifier(class_weight='balanced', random_state=1148093)),
#   ('extraTrees15',
#    ExtraTreesClassifier(class_weight='balanced', random_state=1095286)),
#   ('extraTrees16',
#    ExtraTreesClassifier(class_weight='balanced', random_state=1665788)),
#   ('extraTrees17',
#    ExtraTreesClassifier(class_weight='balanced', random_state=97057)),
#   ('extraTrees18',
#    ExtraTreesClassifier(class_weight='balanced', random_state=152878)),
#   ('extraTrees19',
#    ExtraTreesClassifier(class_weight='balanced', random_state=4543)),
#   ('extraTrees20',
#    ExtraTreesClassifier(class_weight='balanced', random_state=277452)),
#   ('extraTrees21',
#    ExtraTreesClassifier(class_weight='balanced', random_state=295106)),
#   ('extraTrees22',
#    ExtraTreesClassifier(class_weight='balanced', random_state=191278)),
#   ('extraTrees23',
#    ExtraTreesClassifier(class_weight='balanced', random_state=701043)),
#   ('extraTrees24',
#    ExtraTreesClassifier(class_weight='balanced', random_state=81388)),
#   ('extraTrees25',
#    ExtraTreesClassifier(class_weight='balanced', random_state=951209)),
#   ('extraTrees26',
#    ExtraTreesClassifier(class_weight='balanced', random_state=1327001)),
#   ('extraTrees27',
#    ExtraTreesClassifier(class_weight='balanced', random_state=527903)),
#   ('gbc0',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=1148093)),
#   ('gbc1',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=1095286)),
#   ('gbc2',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=1665788)),
#   ('gbc3',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=97057)),
#   ('gbc4',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=152878)),
#   ('gbc5',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=4543)),
#   ('gbc6',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=277452)),
#   ('gbc7',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=295106)),
#   ('gbc8',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=191278)),
#   ('gbc9',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=701043)),
#   ('gbc10',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=81388)),
#   ('gbc11',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=951209)),
#   ('gbc12',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=1327001)),
#   ('gbc13',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=527903)),
#   ('gbc14',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=1148093)),
#   ('gbc15',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=1095286)),
#   ('gbc16',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=1665788)),
#   ('gbc17',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=97057)),
#   ('gbc18',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=152878)),
#   ('gbc19',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=4543)),
#   ('gbc20',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=277452)),
#   ('gbc21',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=295106)),
#   ('gbc22',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=191278)),
#   ('gbc23',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=701043)),
#   ('gbc24',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=81388)),
#   ('gbc25',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=951209)),
#   ('gbc26',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=1327001)),
#   ('gbc27',
#    GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                               random_state=527903)),
#   ('ada0', AdaBoostClassifier(learning_rate=1, random_state=1148093)),
#   ('ada1', AdaBoostClassifier(learning_rate=1, random_state=1095286)),
#   ('ada2', AdaBoostClassifier(learning_rate=1, random_state=1665788)),
#   ('ada3', AdaBoostClassifier(learning_rate=1, random_state=97057)),
#   ('ada4', AdaBoostClassifier(learning_rate=1, random_state=152878)),
#   ('ada5', AdaBoostClassifier(learning_rate=1, random_state=4543)),
#   ('ada6', AdaBoostClassifier(learning_rate=1, random_state=277452)),
#   ('ada7', AdaBoostClassifier(learning_rate=1, random_state=295106)),
#   ('ada8', AdaBoostClassifier(learning_rate=1, random_state=191278)),
#   ('ada9', AdaBoostClassifier(learning_rate=1, random_state=701043)),
#   ('ada10', AdaBoostClassifier(learning_rate=1, random_state=81388)),
#   ('ada11', AdaBoostClassifier(learning_rate=1, random_state=951209)),
#   ('ada12', AdaBoostClassifier(learning_rate=1, random_state=1327001)),
#   ('ada13', AdaBoostClassifier(learning_rate=1, random_state=527903)),
#   ('ada14', AdaBoostClassifier(learning_rate=1, random_state=1148093)),
#   ('ada15', AdaBoostClassifier(learning_rate=1, random_state=1095286)),
#   ('ada16', AdaBoostClassifier(learning_rate=1, random_state=1665788)),
#   ('ada17', AdaBoostClassifier(learning_rate=1, random_state=97057)),
#   ('ada18', AdaBoostClassifier(learning_rate=1, random_state=152878)),
#   ('ada19', AdaBoostClassifier(learning_rate=1, random_state=4543)),
#   ('ada20', AdaBoostClassifier(learning_rate=1, random_state=277452)),
#   ('ada21', AdaBoostClassifier(learning_rate=1, random_state=295106)),
#   ('ada22', AdaBoostClassifier(learning_rate=1, random_state=191278)),
#   ('ada23', AdaBoostClassifier(learning_rate=1, random_state=701043)),
#   ('ada24', AdaBoostClassifier(learning_rate=1, random_state=81388)),
#   ('ada25', AdaBoostClassifier(learning_rate=1, random_state=951209)),
#   ('ada26', AdaBoostClassifier(learning_rate=1, random_state=1327001)),
#   ('ada27', AdaBoostClassifier(learning_rate=1, random_state=527903))],
#  'voting__flatten_transform': True,
#  'voting__n_jobs': -1,
#  'voting__verbose': False,
#  'voting__voting': 'soft',
#  'voting__weights': None,
#  'voting__rf0': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=1148093),
#  'voting__rf1': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=1095286),
#  'voting__rf2': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=1665788),
#  'voting__rf3': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=97057),
#  'voting__rf4': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=152878),
#  'voting__rf5': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=4543),
#  'voting__rf6': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=277452),
#  'voting__rf7': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=295106),
#  'voting__rf8': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=191278),
#  'voting__rf9': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=701043),
#  'voting__rf10': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=81388),
#  'voting__rf11': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=951209),
#  'voting__rf12': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=1327001),
#  'voting__rf13': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=527903),
#  'voting__rf14': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=1148093),
#  'voting__rf15': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=1095286),
#  'voting__rf16': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=1665788),
#  'voting__rf17': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=97057),
#  'voting__rf18': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=152878),
#  'voting__rf19': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=4543),
#  'voting__rf20': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=277452),
#  'voting__rf21': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=295106),
#  'voting__rf22': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=191278),
#  'voting__rf23': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=701043),
#  'voting__rf24': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=81388),
#  'voting__rf25': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=951209),
#  'voting__rf26': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=1327001),
#  'voting__rf27': RandomForestClassifier(class_weight='balanced', max_features='log2',
#                         n_estimators=80, random_state=527903),
#  'voting__extraTrees0': ExtraTreesClassifier(class_weight='balanced', random_state=1148093),
#  'voting__extraTrees1': ExtraTreesClassifier(class_weight='balanced', random_state=1095286),
#  'voting__extraTrees2': ExtraTreesClassifier(class_weight='balanced', random_state=1665788),
#  'voting__extraTrees3': ExtraTreesClassifier(class_weight='balanced', random_state=97057),
#  'voting__extraTrees4': ExtraTreesClassifier(class_weight='balanced', random_state=152878),
#  'voting__extraTrees5': ExtraTreesClassifier(class_weight='balanced', random_state=4543),
#  'voting__extraTrees6': ExtraTreesClassifier(class_weight='balanced', random_state=277452),
#  'voting__extraTrees7': ExtraTreesClassifier(class_weight='balanced', random_state=295106),
#  'voting__extraTrees8': ExtraTreesClassifier(class_weight='balanced', random_state=191278),
#  'voting__extraTrees9': ExtraTreesClassifier(class_weight='balanced', random_state=701043),
#  'voting__extraTrees10': ExtraTreesClassifier(class_weight='balanced', random_state=81388),
#  'voting__extraTrees11': ExtraTreesClassifier(class_weight='balanced', random_state=951209),
#  'voting__extraTrees12': ExtraTreesClassifier(class_weight='balanced', random_state=1327001),
#  'voting__extraTrees13': ExtraTreesClassifier(class_weight='balanced', random_state=527903),
#  'voting__extraTrees14': ExtraTreesClassifier(class_weight='balanced', random_state=1148093),
#  'voting__extraTrees15': ExtraTreesClassifier(class_weight='balanced', random_state=1095286),
#  'voting__extraTrees16': ExtraTreesClassifier(class_weight='balanced', random_state=1665788),
#  'voting__extraTrees17': ExtraTreesClassifier(class_weight='balanced', random_state=97057),
#  'voting__extraTrees18': ExtraTreesClassifier(class_weight='balanced', random_state=152878),
#  'voting__extraTrees19': ExtraTreesClassifier(class_weight='balanced', random_state=4543),
#  'voting__extraTrees20': ExtraTreesClassifier(class_weight='balanced', random_state=277452),
#  'voting__extraTrees21': ExtraTreesClassifier(class_weight='balanced', random_state=295106),
#  'voting__extraTrees22': ExtraTreesClassifier(class_weight='balanced', random_state=191278),
#  'voting__extraTrees23': ExtraTreesClassifier(class_weight='balanced', random_state=701043),
#  'voting__extraTrees24': ExtraTreesClassifier(class_weight='balanced', random_state=81388),
#  'voting__extraTrees25': ExtraTreesClassifier(class_weight='balanced', random_state=951209),
#  'voting__extraTrees26': ExtraTreesClassifier(class_weight='balanced', random_state=1327001),
#  'voting__extraTrees27': ExtraTreesClassifier(class_weight='balanced', random_state=527903),
#  'voting__gbc0': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=1148093),
#  'voting__gbc1': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=1095286),
#  'voting__gbc2': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=1665788),
#  'voting__gbc3': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=97057),
#  'voting__gbc4': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=152878),
#  'voting__gbc5': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=4543),
#  'voting__gbc6': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=277452),
#  'voting__gbc7': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=295106),
#  'voting__gbc8': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=191278),
#  'voting__gbc9': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=701043),
#  'voting__gbc10': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=81388),
#  'voting__gbc11': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=951209),
#  'voting__gbc12': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=1327001),
#  'voting__gbc13': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=527903),
#  'voting__gbc14': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=1148093),
#  'voting__gbc15': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=1095286),
#  'voting__gbc16': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=1665788),
#  'voting__gbc17': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=97057),
#  'voting__gbc18': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=152878),
#  'voting__gbc19': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=4543),
#  'voting__gbc20': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=277452),
#  'voting__gbc21': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=295106),
#  'voting__gbc22': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=191278),
#  'voting__gbc23': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=701043),
#  'voting__gbc24': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=81388),
#  'voting__gbc25': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=951209),
#  'voting__gbc26': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=1327001),
#  'voting__gbc27': GradientBoostingClassifier(max_features='log2', n_estimators=60,
#                             random_state=527903),
#  'voting__ada0': AdaBoostClassifier(learning_rate=1, random_state=1148093),
#  'voting__ada1': AdaBoostClassifier(learning_rate=1, random_state=1095286),
#  'voting__ada2': AdaBoostClassifier(learning_rate=1, random_state=1665788),
#  'voting__ada3': AdaBoostClassifier(learning_rate=1, random_state=97057),
#  'voting__ada4': AdaBoostClassifier(learning_rate=1, random_state=152878),
#  'voting__ada5': AdaBoostClassifier(learning_rate=1, random_state=4543),
#  'voting__ada6': AdaBoostClassifier(learning_rate=1, random_state=277452),
#  'voting__ada7': AdaBoostClassifier(learning_rate=1, random_state=295106),
#  'voting__ada8': AdaBoostClassifier(learning_rate=1, random_state=191278),
#  'voting__ada9': AdaBoostClassifier(learning_rate=1, random_state=701043),
#  'voting__ada10': AdaBoostClassifier(learning_rate=1, random_state=81388),
#  'voting__ada11': AdaBoostClassifier(learning_rate=1, random_state=951209),
#  'voting__ada12': AdaBoostClassifier(learning_rate=1, random_state=1327001),
#  'voting__ada13': AdaBoostClassifier(learning_rate=1, random_state=527903),
#  'voting__ada14': AdaBoostClassifier(learning_rate=1, random_state=1148093),
#  'voting__ada15': AdaBoostClassifier(learning_rate=1, random_state=1095286),
#  'voting__ada16': AdaBoostClassifier(learning_rate=1, random_state=1665788),
#  'voting__ada17': AdaBoostClassifier(learning_rate=1, random_state=97057),
#  'voting__ada18': AdaBoostClassifier(learning_rate=1, random_state=152878),
#  'voting__ada19': AdaBoostClassifier(learning_rate=1, random_state=4543),
#  'voting__ada20': AdaBoostClassifier(learning_rate=1, random_state=277452),
#  'voting__ada21': AdaBoostClassifier(learning_rate=1, random_state=295106),
#  'voting__ada22': AdaBoostClassifier(learning_rate=1, random_state=191278),
#  'voting__ada23': AdaBoostClassifier(learning_rate=1, random_state=701043),
#  'voting__ada24': AdaBoostClassifier(learning_rate=1, random_state=81388),
#  'voting__ada25': AdaBoostClassifier(learning_rate=1, random_state=951209),
#  'voting__ada26': AdaBoostClassifier(learning_rate=1, random_state=1327001),
#  'voting__ada27': AdaBoostClassifier(learning_rate=1, random_state=527903),
#  'voting__rf0__bootstrap': True,
#  'voting__rf0__ccp_alpha': 0.0,
#  'voting__rf0__class_weight': 'balanced',
#  'voting__rf0__criterion': 'gini',
#  'voting__rf0__max_depth': None,
#  'voting__rf0__max_features': 'log2',
#  'voting__rf0__max_leaf_nodes': None,
#  'voting__rf0__max_samples': None,
#  'voting__rf0__min_impurity_decrease': 0.0,
#  'voting__rf0__min_samples_leaf': 1,
#  'voting__rf0__min_samples_split': 2,
#  'voting__rf0__min_weight_fraction_leaf': 0.0,
#  'voting__rf0__n_estimators': 80,
#  'voting__rf0__n_jobs': None,
#  'voting__rf0__oob_score': False,
#  'voting__rf0__random_state': 1148093,
#  'voting__rf0__verbose': 0,
#  'voting__rf0__warm_start': False,
#  'voting__rf1__bootstrap': True,
#  'voting__rf1__ccp_alpha': 0.0,
#  'voting__rf1__class_weight': 'balanced',
#  'voting__rf1__criterion': 'gini',
#  'voting__rf1__max_depth': None,
#  'voting__rf1__max_features': 'log2',
#  'voting__rf1__max_leaf_nodes': None,
#  'voting__rf1__max_samples': None,
#  'voting__rf1__min_impurity_decrease': 0.0,
#  'voting__rf1__min_samples_leaf': 1,
#  'voting__rf1__min_samples_split': 2,
#  'voting__rf1__min_weight_fraction_leaf': 0.0,
#  'voting__rf1__n_estimators': 80,
#  'voting__rf1__n_jobs': None,
#  'voting__rf1__oob_score': False,
#  'voting__rf1__random_state': 1095286,
#  'voting__rf1__verbose': 0,
#  'voting__rf1__warm_start': False,
#  'voting__rf2__bootstrap': True,
#  'voting__rf2__ccp_alpha': 0.0,
#  'voting__rf2__class_weight': 'balanced',
#  'voting__rf2__criterion': 'gini',
#  'voting__rf2__max_depth': None,
#  'voting__rf2__max_features': 'log2',
#  'voting__rf2__max_leaf_nodes': None,
#  'voting__rf2__max_samples': None,
#  'voting__rf2__min_impurity_decrease': 0.0,
#  'voting__rf2__min_samples_leaf': 1,
#  'voting__rf2__min_samples_split': 2,
#  'voting__rf2__min_weight_fraction_leaf': 0.0,
#  'voting__rf2__n_estimators': 80,
#  'voting__rf2__n_jobs': None,
#  'voting__rf2__oob_score': False,
#  'voting__rf2__random_state': 1665788,
#  'voting__rf2__verbose': 0,
#  'voting__rf2__warm_start': False,
#  'voting__rf3__bootstrap': True,
#  'voting__rf3__ccp_alpha': 0.0,
#  'voting__rf3__class_weight': 'balanced',
#  'voting__rf3__criterion': 'gini',
#  'voting__rf3__max_depth': None,
#  'voting__rf3__max_features': 'log2',
#  'voting__rf3__max_leaf_nodes': None,
#  'voting__rf3__max_samples': None,
#  'voting__rf3__min_impurity_decrease': 0.0,
#  'voting__rf3__min_samples_leaf': 1,
#  'voting__rf3__min_samples_split': 2,
#  'voting__rf3__min_weight_fraction_leaf': 0.0,
#  'voting__rf3__n_estimators': 80,
#  'voting__rf3__n_jobs': None,
#  'voting__rf3__oob_score': False,
#  'voting__rf3__random_state': 97057,
#  'voting__rf3__verbose': 0,
#  'voting__rf3__warm_start': False,
#  'voting__rf4__bootstrap': True,
#  'voting__rf4__ccp_alpha': 0.0,
#  'voting__rf4__class_weight': 'balanced',
#  'voting__rf4__criterion': 'gini',
#  'voting__rf4__max_depth': None,
#  'voting__rf4__max_features': 'log2',
#  'voting__rf4__max_leaf_nodes': None,
#  'voting__rf4__max_samples': None,
#  'voting__rf4__min_impurity_decrease': 0.0,
#  'voting__rf4__min_samples_leaf': 1,
#  'voting__rf4__min_samples_split': 2,
#  'voting__rf4__min_weight_fraction_leaf': 0.0,
#  'voting__rf4__n_estimators': 80,
#  'voting__rf4__n_jobs': None,
#  'voting__rf4__oob_score': False,
#  'voting__rf4__random_state': 152878,
#  'voting__rf4__verbose': 0,
#  'voting__rf4__warm_start': False,
#  'voting__rf5__bootstrap': True,
#  'voting__rf5__ccp_alpha': 0.0,
#  'voting__rf5__class_weight': 'balanced',
#  'voting__rf5__criterion': 'gini',
#  'voting__rf5__max_depth': None,
#  'voting__rf5__max_features': 'log2',
#  'voting__rf5__max_leaf_nodes': None,
#  'voting__rf5__max_samples': None,
#  'voting__rf5__min_impurity_decrease': 0.0,
#  'voting__rf5__min_samples_leaf': 1,
#  'voting__rf5__min_samples_split': 2,
#  'voting__rf5__min_weight_fraction_leaf': 0.0,
#  'voting__rf5__n_estimators': 80,
#  'voting__rf5__n_jobs': None,
#  'voting__rf5__oob_score': False,
#  'voting__rf5__random_state': 4543,
#  'voting__rf5__verbose': 0,
#  'voting__rf5__warm_start': False,
#  'voting__rf6__bootstrap': True,
#  'voting__rf6__ccp_alpha': 0.0,
#  'voting__rf6__class_weight': 'balanced',
#  'voting__rf6__criterion': 'gini',
#  'voting__rf6__max_depth': None,
#  'voting__rf6__max_features': 'log2',
#  'voting__rf6__max_leaf_nodes': None,
#  'voting__rf6__max_samples': None,
#  'voting__rf6__min_impurity_decrease': 0.0,
#  'voting__rf6__min_samples_leaf': 1,
#  'voting__rf6__min_samples_split': 2,
#  'voting__rf6__min_weight_fraction_leaf': 0.0,
#  'voting__rf6__n_estimators': 80,
#  'voting__rf6__n_jobs': None,
#  'voting__rf6__oob_score': False,
#  'voting__rf6__random_state': 277452,
#  'voting__rf6__verbose': 0,
#  'voting__rf6__warm_start': False,
#  'voting__rf7__bootstrap': True,
#  'voting__rf7__ccp_alpha': 0.0,
#  'voting__rf7__class_weight': 'balanced',
#  'voting__rf7__criterion': 'gini',
#  'voting__rf7__max_depth': None,
#  'voting__rf7__max_features': 'log2',
#  'voting__rf7__max_leaf_nodes': None,
#  'voting__rf7__max_samples': None,
#  'voting__rf7__min_impurity_decrease': 0.0,
#  'voting__rf7__min_samples_leaf': 1,
#  'voting__rf7__min_samples_split': 2,
#  'voting__rf7__min_weight_fraction_leaf': 0.0,
#  'voting__rf7__n_estimators': 80,
#  'voting__rf7__n_jobs': None,
#  'voting__rf7__oob_score': False,
#  'voting__rf7__random_state': 295106,
#  'voting__rf7__verbose': 0,
#  'voting__rf7__warm_start': False,
#  'voting__rf8__bootstrap': True,
#  'voting__rf8__ccp_alpha': 0.0,
#  'voting__rf8__class_weight': 'balanced',
#  'voting__rf8__criterion': 'gini',
#  'voting__rf8__max_depth': None,
#  'voting__rf8__max_features': 'log2',
#  'voting__rf8__max_leaf_nodes': None,
#  'voting__rf8__max_samples': None,
#  'voting__rf8__min_impurity_decrease': 0.0,
#  'voting__rf8__min_samples_leaf': 1,
#  'voting__rf8__min_samples_split': 2,
#  'voting__rf8__min_weight_fraction_leaf': 0.0,
#  'voting__rf8__n_estimators': 80,
#  'voting__rf8__n_jobs': None,
#  'voting__rf8__oob_score': False,
#  'voting__rf8__random_state': 191278,
#  'voting__rf8__verbose': 0,
#  'voting__rf8__warm_start': False,
#  'voting__rf9__bootstrap': True,
#  'voting__rf9__ccp_alpha': 0.0,
#  'voting__rf9__class_weight': 'balanced',
#  'voting__rf9__criterion': 'gini',
#  'voting__rf9__max_depth': None,
#  'voting__rf9__max_features': 'log2',
#  'voting__rf9__max_leaf_nodes': None,
#  'voting__rf9__max_samples': None,
#  'voting__rf9__min_impurity_decrease': 0.0,
#  'voting__rf9__min_samples_leaf': 1,
#  'voting__rf9__min_samples_split': 2,
#  'voting__rf9__min_weight_fraction_leaf': 0.0,
#  'voting__rf9__n_estimators': 80,
#  'voting__rf9__n_jobs': None,
#  'voting__rf9__oob_score': False,
#  'voting__rf9__random_state': 701043,
#  'voting__rf9__verbose': 0,
#  'voting__rf9__warm_start': False,
#  'voting__rf10__bootstrap': True,
#  'voting__rf10__ccp_alpha': 0.0,
#  'voting__rf10__class_weight': 'balanced',
#  'voting__rf10__criterion': 'gini',
#  'voting__rf10__max_depth': None,
#  'voting__rf10__max_features': 'log2',
#  'voting__rf10__max_leaf_nodes': None,
#  'voting__rf10__max_samples': None,
#  'voting__rf10__min_impurity_decrease': 0.0,
#  'voting__rf10__min_samples_leaf': 1,
#  'voting__rf10__min_samples_split': 2,
#  'voting__rf10__min_weight_fraction_leaf': 0.0,
#  'voting__rf10__n_estimators': 80,
#  'voting__rf10__n_jobs': None,
#  'voting__rf10__oob_score': False,
#  'voting__rf10__random_state': 81388,
#  'voting__rf10__verbose': 0,
#  'voting__rf10__warm_start': False,
#  'voting__rf11__bootstrap': True,
#  'voting__rf11__ccp_alpha': 0.0,
#  'voting__rf11__class_weight': 'balanced',
#  'voting__rf11__criterion': 'gini',
#  'voting__rf11__max_depth': None,
#  'voting__rf11__max_features': 'log2',
#  'voting__rf11__max_leaf_nodes': None,
#  'voting__rf11__max_samples': None,
#  'voting__rf11__min_impurity_decrease': 0.0,
#  'voting__rf11__min_samples_leaf': 1,
#  'voting__rf11__min_samples_split': 2,
#  'voting__rf11__min_weight_fraction_leaf': 0.0,
#  'voting__rf11__n_estimators': 80,
#  'voting__rf11__n_jobs': None,
#  'voting__rf11__oob_score': False,
#  'voting__rf11__random_state': 951209,
#  'voting__rf11__verbose': 0,
#  'voting__rf11__warm_start': False,
#  'voting__rf12__bootstrap': True,
#  'voting__rf12__ccp_alpha': 0.0,
#  'voting__rf12__class_weight': 'balanced',
#  'voting__rf12__criterion': 'gini',
#  'voting__rf12__max_depth': None,
#  'voting__rf12__max_features': 'log2',
#  'voting__rf12__max_leaf_nodes': None,
#  'voting__rf12__max_samples': None,
#  'voting__rf12__min_impurity_decrease': 0.0,
#  'voting__rf12__min_samples_leaf': 1,
#  'voting__rf12__min_samples_split': 2,
#  'voting__rf12__min_weight_fraction_leaf': 0.0,
#  'voting__rf12__n_estimators': 80,
#  'voting__rf12__n_jobs': None,
#  'voting__rf12__oob_score': False,
#  'voting__rf12__random_state': 1327001,
#  'voting__rf12__verbose': 0,
#  'voting__rf12__warm_start': False,
#  'voting__rf13__bootstrap': True,
#  'voting__rf13__ccp_alpha': 0.0,
#  'voting__rf13__class_weight': 'balanced',
#  'voting__rf13__criterion': 'gini',
#  'voting__rf13__max_depth': None,
#  'voting__rf13__max_features': 'log2',
#  'voting__rf13__max_leaf_nodes': None,
#  'voting__rf13__max_samples': None,
#  'voting__rf13__min_impurity_decrease': 0.0,
#  'voting__rf13__min_samples_leaf': 1,
#  'voting__rf13__min_samples_split': 2,
#  'voting__rf13__min_weight_fraction_leaf': 0.0,
#  'voting__rf13__n_estimators': 80,
#  'voting__rf13__n_jobs': None,
#  'voting__rf13__oob_score': False,
#  'voting__rf13__random_state': 527903,
#  'voting__rf13__verbose': 0,
#  'voting__rf13__warm_start': False,
#  'voting__rf14__bootstrap': True,
#  'voting__rf14__ccp_alpha': 0.0,
#  'voting__rf14__class_weight': 'balanced',
#  'voting__rf14__criterion': 'gini',
#  'voting__rf14__max_depth': None,
#  'voting__rf14__max_features': 'log2',
#  'voting__rf14__max_leaf_nodes': None,
#  'voting__rf14__max_samples': None,
#  'voting__rf14__min_impurity_decrease': 0.0,
#  'voting__rf14__min_samples_leaf': 1,
#  'voting__rf14__min_samples_split': 2,
#  'voting__rf14__min_weight_fraction_leaf': 0.0,
#  'voting__rf14__n_estimators': 80,
#  'voting__rf14__n_jobs': None,
#  'voting__rf14__oob_score': False,
#  'voting__rf14__random_state': 1148093,
#  'voting__rf14__verbose': 0,
#  'voting__rf14__warm_start': False,
#  'voting__rf15__bootstrap': True,
#  'voting__rf15__ccp_alpha': 0.0,
#  'voting__rf15__class_weight': 'balanced',
#  'voting__rf15__criterion': 'gini',
#  'voting__rf15__max_depth': None,
#  'voting__rf15__max_features': 'log2',
#  'voting__rf15__max_leaf_nodes': None,
#  'voting__rf15__max_samples': None,
#  'voting__rf15__min_impurity_decrease': 0.0,
#  'voting__rf15__min_samples_leaf': 1,
#  'voting__rf15__min_samples_split': 2,
#  'voting__rf15__min_weight_fraction_leaf': 0.0,
#  'voting__rf15__n_estimators': 80,
#  'voting__rf15__n_jobs': None,
#  'voting__rf15__oob_score': False,
#  'voting__rf15__random_state': 1095286,
#  'voting__rf15__verbose': 0,
#  'voting__rf15__warm_start': False,
#  'voting__rf16__bootstrap': True,
#  'voting__rf16__ccp_alpha': 0.0,
#  'voting__rf16__class_weight': 'balanced',
#  'voting__rf16__criterion': 'gini',
#  'voting__rf16__max_depth': None,
#  'voting__rf16__max_features': 'log2',
#  'voting__rf16__max_leaf_nodes': None,
#  'voting__rf16__max_samples': None,
#  'voting__rf16__min_impurity_decrease': 0.0,
#  'voting__rf16__min_samples_leaf': 1,
#  'voting__rf16__min_samples_split': 2,
#  'voting__rf16__min_weight_fraction_leaf': 0.0,
#  'voting__rf16__n_estimators': 80,
#  'voting__rf16__n_jobs': None,
#  'voting__rf16__oob_score': False,
#  'voting__rf16__random_state': 1665788,
#  'voting__rf16__verbose': 0,
#  'voting__rf16__warm_start': False,
#  'voting__rf17__bootstrap': True,
#  'voting__rf17__ccp_alpha': 0.0,
#  'voting__rf17__class_weight': 'balanced',
#  'voting__rf17__criterion': 'gini',
#  'voting__rf17__max_depth': None,
#  'voting__rf17__max_features': 'log2',
#  'voting__rf17__max_leaf_nodes': None,
#  'voting__rf17__max_samples': None,
#  'voting__rf17__min_impurity_decrease': 0.0,
#  'voting__rf17__min_samples_leaf': 1,
#  'voting__rf17__min_samples_split': 2,
#  'voting__rf17__min_weight_fraction_leaf': 0.0,
#  'voting__rf17__n_estimators': 80,
#  'voting__rf17__n_jobs': None,
#  'voting__rf17__oob_score': False,
#  'voting__rf17__random_state': 97057,
#  'voting__rf17__verbose': 0,
#  'voting__rf17__warm_start': False,
#  'voting__rf18__bootstrap': True,
#  'voting__rf18__ccp_alpha': 0.0,
#  'voting__rf18__class_weight': 'balanced',
#  'voting__rf18__criterion': 'gini',
#  'voting__rf18__max_depth': None,
#  'voting__rf18__max_features': 'log2',
#  'voting__rf18__max_leaf_nodes': None,
#  'voting__rf18__max_samples': None,
#  'voting__rf18__min_impurity_decrease': 0.0,
#  'voting__rf18__min_samples_leaf': 1,
#  'voting__rf18__min_samples_split': 2,
#  'voting__rf18__min_weight_fraction_leaf': 0.0,
#  'voting__rf18__n_estimators': 80,
#  'voting__rf18__n_jobs': None,
#  'voting__rf18__oob_score': False,
#  'voting__rf18__random_state': 152878,
#  'voting__rf18__verbose': 0,
#  'voting__rf18__warm_start': False,
#  'voting__rf19__bootstrap': True,
#  'voting__rf19__ccp_alpha': 0.0,
#  'voting__rf19__class_weight': 'balanced',
#  'voting__rf19__criterion': 'gini',
#  'voting__rf19__max_depth': None,
#  'voting__rf19__max_features': 'log2',
#  'voting__rf19__max_leaf_nodes': None,
#  'voting__rf19__max_samples': None,
#  'voting__rf19__min_impurity_decrease': 0.0,
#  'voting__rf19__min_samples_leaf': 1,
#  'voting__rf19__min_samples_split': 2,
#  'voting__rf19__min_weight_fraction_leaf': 0.0,
#  'voting__rf19__n_estimators': 80,
#  'voting__rf19__n_jobs': None,
#  'voting__rf19__oob_score': False,
#  'voting__rf19__random_state': 4543,
#  'voting__rf19__verbose': 0,
#  'voting__rf19__warm_start': False,
#  'voting__rf20__bootstrap': True,
#  'voting__rf20__ccp_alpha': 0.0,
#  'voting__rf20__class_weight': 'balanced',
#  'voting__rf20__criterion': 'gini',
#  'voting__rf20__max_depth': None,
#  'voting__rf20__max_features': 'log2',
#  'voting__rf20__max_leaf_nodes': None,
#  'voting__rf20__max_samples': None,
#  'voting__rf20__min_impurity_decrease': 0.0,
#  'voting__rf20__min_samples_leaf': 1,
#  'voting__rf20__min_samples_split': 2,
#  'voting__rf20__min_weight_fraction_leaf': 0.0,
#  'voting__rf20__n_estimators': 80,
#  'voting__rf20__n_jobs': None,
#  'voting__rf20__oob_score': False,
#  'voting__rf20__random_state': 277452,
#  'voting__rf20__verbose': 0,
#  'voting__rf20__warm_start': False,
#  'voting__rf21__bootstrap': True,
#  'voting__rf21__ccp_alpha': 0.0,
#  'voting__rf21__class_weight': 'balanced',
#  'voting__rf21__criterion': 'gini',
#  'voting__rf21__max_depth': None,
#  'voting__rf21__max_features': 'log2',
#  'voting__rf21__max_leaf_nodes': None,
#  'voting__rf21__max_samples': None,
#  'voting__rf21__min_impurity_decrease': 0.0,
#  'voting__rf21__min_samples_leaf': 1,
#  'voting__rf21__min_samples_split': 2,
#  'voting__rf21__min_weight_fraction_leaf': 0.0,
#  'voting__rf21__n_estimators': 80,
#  'voting__rf21__n_jobs': None,
#  'voting__rf21__oob_score': False,
#  'voting__rf21__random_state': 295106,
#  'voting__rf21__verbose': 0,
#  'voting__rf21__warm_start': False,
#  'voting__rf22__bootstrap': True,
#  'voting__rf22__ccp_alpha': 0.0,
#  'voting__rf22__class_weight': 'balanced',
#  'voting__rf22__criterion': 'gini',
#  'voting__rf22__max_depth': None,
#  'voting__rf22__max_features': 'log2',
#  'voting__rf22__max_leaf_nodes': None,
#  'voting__rf22__max_samples': None,
#  'voting__rf22__min_impurity_decrease': 0.0,
#  'voting__rf22__min_samples_leaf': 1,
#  'voting__rf22__min_samples_split': 2,
#  'voting__rf22__min_weight_fraction_leaf': 0.0,
#  'voting__rf22__n_estimators': 80,
#  'voting__rf22__n_jobs': None,
#  'voting__rf22__oob_score': False,
#  'voting__rf22__random_state': 191278,
#  'voting__rf22__verbose': 0,
#  'voting__rf22__warm_start': False,
#  'voting__rf23__bootstrap': True,
#  'voting__rf23__ccp_alpha': 0.0,
#  'voting__rf23__class_weight': 'balanced',
#  'voting__rf23__criterion': 'gini',
#  'voting__rf23__max_depth': None,
#  'voting__rf23__max_features': 'log2',
#  'voting__rf23__max_leaf_nodes': None,
#  'voting__rf23__max_samples': None,
#  'voting__rf23__min_impurity_decrease': 0.0,
#  'voting__rf23__min_samples_leaf': 1,
#  'voting__rf23__min_samples_split': 2,
#  'voting__rf23__min_weight_fraction_leaf': 0.0,
#  'voting__rf23__n_estimators': 80,
#  'voting__rf23__n_jobs': None,
#  'voting__rf23__oob_score': False,
#  'voting__rf23__random_state': 701043,
#  'voting__rf23__verbose': 0,
#  'voting__rf23__warm_start': False,
#  'voting__rf24__bootstrap': True,
#  'voting__rf24__ccp_alpha': 0.0,
#  'voting__rf24__class_weight': 'balanced',
#  'voting__rf24__criterion': 'gini',
#  'voting__rf24__max_depth': None,
#  'voting__rf24__max_features': 'log2',
#  'voting__rf24__max_leaf_nodes': None,
#  'voting__rf24__max_samples': None,
#  'voting__rf24__min_impurity_decrease': 0.0,
#  'voting__rf24__min_samples_leaf': 1,
#  'voting__rf24__min_samples_split': 2,
#  'voting__rf24__min_weight_fraction_leaf': 0.0,
#  'voting__rf24__n_estimators': 80,
#  'voting__rf24__n_jobs': None,
#  'voting__rf24__oob_score': False,
#  'voting__rf24__random_state': 81388,
#  'voting__rf24__verbose': 0,
#  'voting__rf24__warm_start': False,
#  'voting__rf25__bootstrap': True,
#  'voting__rf25__ccp_alpha': 0.0,
#  'voting__rf25__class_weight': 'balanced',
#  'voting__rf25__criterion': 'gini',
#  'voting__rf25__max_depth': None,
#  'voting__rf25__max_features': 'log2',
#  'voting__rf25__max_leaf_nodes': None,
#  'voting__rf25__max_samples': None,
#  'voting__rf25__min_impurity_decrease': 0.0,
#  'voting__rf25__min_samples_leaf': 1,
#  'voting__rf25__min_samples_split': 2,
#  'voting__rf25__min_weight_fraction_leaf': 0.0,
#  'voting__rf25__n_estimators': 80,
#  'voting__rf25__n_jobs': None,
#  'voting__rf25__oob_score': False,
#  'voting__rf25__random_state': 951209,
#  'voting__rf25__verbose': 0,
#  'voting__rf25__warm_start': False,
#  'voting__rf26__bootstrap': True,
#  'voting__rf26__ccp_alpha': 0.0,
#  'voting__rf26__class_weight': 'balanced',
#  'voting__rf26__criterion': 'gini',
#  'voting__rf26__max_depth': None,
#  'voting__rf26__max_features': 'log2',
#  'voting__rf26__max_leaf_nodes': None,
#  'voting__rf26__max_samples': None,
#  'voting__rf26__min_impurity_decrease': 0.0,
#  'voting__rf26__min_samples_leaf': 1,
#  'voting__rf26__min_samples_split': 2,
#  'voting__rf26__min_weight_fraction_leaf': 0.0,
#  'voting__rf26__n_estimators': 80,
#  'voting__rf26__n_jobs': None,
#  'voting__rf26__oob_score': False,
#  'voting__rf26__random_state': 1327001,
#  'voting__rf26__verbose': 0,
#  'voting__rf26__warm_start': False,
#  'voting__rf27__bootstrap': True,
#  'voting__rf27__ccp_alpha': 0.0,
#  'voting__rf27__class_weight': 'balanced',
#  'voting__rf27__criterion': 'gini',
#  'voting__rf27__max_depth': None,
#  'voting__rf27__max_features': 'log2',
#  'voting__rf27__max_leaf_nodes': None,
#  'voting__rf27__max_samples': None,
#  'voting__rf27__min_impurity_decrease': 0.0,
#  'voting__rf27__min_samples_leaf': 1,
#  'voting__rf27__min_samples_split': 2,
#  'voting__rf27__min_weight_fraction_leaf': 0.0,
#  'voting__rf27__n_estimators': 80,
#  'voting__rf27__n_jobs': None,
#  'voting__rf27__oob_score': False,
#  'voting__rf27__random_state': 527903,
#  'voting__rf27__verbose': 0,
# ...
#  'voting__extraTrees0__n_jobs': None,
#  'voting__extraTrees0__oob_score': False,
#  'voting__extraTrees0__random_state': 1148093,
#  'voting__extraTrees0__verbose': 0,
#  'voting__extraTrees0__warm_start': False,
#  'voting__extraTrees1__bootstrap': False,
#  'voting__extraTrees1__ccp_alpha': 0.0,
#  'voting__extraTrees1__class_weight': 'balanced',
#  'voting__extraTrees1__criterion': 'gini',
#  'voting__extraTrees1__max_depth': None,
#  'voting__extraTrees1__max_features': 'sqrt',
#  'voting__extraTrees1__max_leaf_nodes': None,
#  'voting__extraTrees1__max_samples': None,
#  'voting__extraTrees1__min_impurity_decrease': 0.0,
#  'voting__extraTrees1__min_samples_leaf': 1,
#  'voting__extraTrees1__min_samples_split': 2,
#  'voting__extraTrees1__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees1__n_estimators': 100,
#  'voting__extraTrees1__n_jobs': None,
#  'voting__extraTrees1__oob_score': False,
#  'voting__extraTrees1__random_state': 1095286,
#  'voting__extraTrees1__verbose': 0,
#  'voting__extraTrees1__warm_start': False,
#  'voting__extraTrees2__bootstrap': False,
#  'voting__extraTrees2__ccp_alpha': 0.0,
#  'voting__extraTrees2__class_weight': 'balanced',
#  'voting__extraTrees2__criterion': 'gini',
#  'voting__extraTrees2__max_depth': None,
#  'voting__extraTrees2__max_features': 'sqrt',
#  'voting__extraTrees2__max_leaf_nodes': None,
#  'voting__extraTrees2__max_samples': None,
#  'voting__extraTrees2__min_impurity_decrease': 0.0,
#  'voting__extraTrees2__min_samples_leaf': 1,
#  'voting__extraTrees2__min_samples_split': 2,
#  'voting__extraTrees2__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees2__n_estimators': 100,
#  'voting__extraTrees2__n_jobs': None,
#  'voting__extraTrees2__oob_score': False,
#  'voting__extraTrees2__random_state': 1665788,
#  'voting__extraTrees2__verbose': 0,
#  'voting__extraTrees2__warm_start': False,
#  'voting__extraTrees3__bootstrap': False,
#  'voting__extraTrees3__ccp_alpha': 0.0,
#  'voting__extraTrees3__class_weight': 'balanced',
#  'voting__extraTrees3__criterion': 'gini',
#  'voting__extraTrees3__max_depth': None,
#  'voting__extraTrees3__max_features': 'sqrt',
#  'voting__extraTrees3__max_leaf_nodes': None,
#  'voting__extraTrees3__max_samples': None,
#  'voting__extraTrees3__min_impurity_decrease': 0.0,
#  'voting__extraTrees3__min_samples_leaf': 1,
#  'voting__extraTrees3__min_samples_split': 2,
#  'voting__extraTrees3__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees3__n_estimators': 100,
#  'voting__extraTrees3__n_jobs': None,
#  'voting__extraTrees3__oob_score': False,
#  'voting__extraTrees3__random_state': 97057,
#  'voting__extraTrees3__verbose': 0,
#  'voting__extraTrees3__warm_start': False,
#  'voting__extraTrees4__bootstrap': False,
#  'voting__extraTrees4__ccp_alpha': 0.0,
#  'voting__extraTrees4__class_weight': 'balanced',
#  'voting__extraTrees4__criterion': 'gini',
#  'voting__extraTrees4__max_depth': None,
#  'voting__extraTrees4__max_features': 'sqrt',
#  'voting__extraTrees4__max_leaf_nodes': None,
#  'voting__extraTrees4__max_samples': None,
#  'voting__extraTrees4__min_impurity_decrease': 0.0,
#  'voting__extraTrees4__min_samples_leaf': 1,
#  'voting__extraTrees4__min_samples_split': 2,
#  'voting__extraTrees4__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees4__n_estimators': 100,
#  'voting__extraTrees4__n_jobs': None,
#  'voting__extraTrees4__oob_score': False,
#  'voting__extraTrees4__random_state': 152878,
#  'voting__extraTrees4__verbose': 0,
#  'voting__extraTrees4__warm_start': False,
#  'voting__extraTrees5__bootstrap': False,
#  'voting__extraTrees5__ccp_alpha': 0.0,
#  'voting__extraTrees5__class_weight': 'balanced',
#  'voting__extraTrees5__criterion': 'gini',
#  'voting__extraTrees5__max_depth': None,
#  'voting__extraTrees5__max_features': 'sqrt',
#  'voting__extraTrees5__max_leaf_nodes': None,
#  'voting__extraTrees5__max_samples': None,
#  'voting__extraTrees5__min_impurity_decrease': 0.0,
#  'voting__extraTrees5__min_samples_leaf': 1,
#  'voting__extraTrees5__min_samples_split': 2,
#  'voting__extraTrees5__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees5__n_estimators': 100,
#  'voting__extraTrees5__n_jobs': None,
#  'voting__extraTrees5__oob_score': False,
#  'voting__extraTrees5__random_state': 4543,
#  'voting__extraTrees5__verbose': 0,
#  'voting__extraTrees5__warm_start': False,
#  'voting__extraTrees6__bootstrap': False,
#  'voting__extraTrees6__ccp_alpha': 0.0,
#  'voting__extraTrees6__class_weight': 'balanced',
#  'voting__extraTrees6__criterion': 'gini',
#  'voting__extraTrees6__max_depth': None,
#  'voting__extraTrees6__max_features': 'sqrt',
#  'voting__extraTrees6__max_leaf_nodes': None,
#  'voting__extraTrees6__max_samples': None,
#  'voting__extraTrees6__min_impurity_decrease': 0.0,
#  'voting__extraTrees6__min_samples_leaf': 1,
#  'voting__extraTrees6__min_samples_split': 2,
#  'voting__extraTrees6__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees6__n_estimators': 100,
#  'voting__extraTrees6__n_jobs': None,
#  'voting__extraTrees6__oob_score': False,
#  'voting__extraTrees6__random_state': 277452,
#  'voting__extraTrees6__verbose': 0,
#  'voting__extraTrees6__warm_start': False,
#  'voting__extraTrees7__bootstrap': False,
#  'voting__extraTrees7__ccp_alpha': 0.0,
#  'voting__extraTrees7__class_weight': 'balanced',
#  'voting__extraTrees7__criterion': 'gini',
#  'voting__extraTrees7__max_depth': None,
#  'voting__extraTrees7__max_features': 'sqrt',
#  'voting__extraTrees7__max_leaf_nodes': None,
#  'voting__extraTrees7__max_samples': None,
#  'voting__extraTrees7__min_impurity_decrease': 0.0,
#  'voting__extraTrees7__min_samples_leaf': 1,
#  'voting__extraTrees7__min_samples_split': 2,
#  'voting__extraTrees7__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees7__n_estimators': 100,
#  'voting__extraTrees7__n_jobs': None,
#  'voting__extraTrees7__oob_score': False,
#  'voting__extraTrees7__random_state': 295106,
#  'voting__extraTrees7__verbose': 0,
#  'voting__extraTrees7__warm_start': False,
#  'voting__extraTrees8__bootstrap': False,
#  'voting__extraTrees8__ccp_alpha': 0.0,
#  'voting__extraTrees8__class_weight': 'balanced',
#  'voting__extraTrees8__criterion': 'gini',
#  'voting__extraTrees8__max_depth': None,
#  'voting__extraTrees8__max_features': 'sqrt',
#  'voting__extraTrees8__max_leaf_nodes': None,
#  'voting__extraTrees8__max_samples': None,
#  'voting__extraTrees8__min_impurity_decrease': 0.0,
#  'voting__extraTrees8__min_samples_leaf': 1,
#  'voting__extraTrees8__min_samples_split': 2,
#  'voting__extraTrees8__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees8__n_estimators': 100,
#  'voting__extraTrees8__n_jobs': None,
#  'voting__extraTrees8__oob_score': False,
#  'voting__extraTrees8__random_state': 191278,
#  'voting__extraTrees8__verbose': 0,
#  'voting__extraTrees8__warm_start': False,
#  'voting__extraTrees9__bootstrap': False,
#  'voting__extraTrees9__ccp_alpha': 0.0,
#  'voting__extraTrees9__class_weight': 'balanced',
#  'voting__extraTrees9__criterion': 'gini',
#  'voting__extraTrees9__max_depth': None,
#  'voting__extraTrees9__max_features': 'sqrt',
#  'voting__extraTrees9__max_leaf_nodes': None,
#  'voting__extraTrees9__max_samples': None,
#  'voting__extraTrees9__min_impurity_decrease': 0.0,
#  'voting__extraTrees9__min_samples_leaf': 1,
#  'voting__extraTrees9__min_samples_split': 2,
#  'voting__extraTrees9__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees9__n_estimators': 100,
#  'voting__extraTrees9__n_jobs': None,
#  'voting__extraTrees9__oob_score': False,
#  'voting__extraTrees9__random_state': 701043,
#  'voting__extraTrees9__verbose': 0,
#  'voting__extraTrees9__warm_start': False,
#  'voting__extraTrees10__bootstrap': False,
#  'voting__extraTrees10__ccp_alpha': 0.0,
#  'voting__extraTrees10__class_weight': 'balanced',
#  'voting__extraTrees10__criterion': 'gini',
#  'voting__extraTrees10__max_depth': None,
#  'voting__extraTrees10__max_features': 'sqrt',
#  'voting__extraTrees10__max_leaf_nodes': None,
#  'voting__extraTrees10__max_samples': None,
#  'voting__extraTrees10__min_impurity_decrease': 0.0,
#  'voting__extraTrees10__min_samples_leaf': 1,
#  'voting__extraTrees10__min_samples_split': 2,
#  'voting__extraTrees10__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees10__n_estimators': 100,
#  'voting__extraTrees10__n_jobs': None,
#  'voting__extraTrees10__oob_score': False,
#  'voting__extraTrees10__random_state': 81388,
#  'voting__extraTrees10__verbose': 0,
#  'voting__extraTrees10__warm_start': False,
#  'voting__extraTrees11__bootstrap': False,
#  'voting__extraTrees11__ccp_alpha': 0.0,
#  'voting__extraTrees11__class_weight': 'balanced',
#  'voting__extraTrees11__criterion': 'gini',
#  'voting__extraTrees11__max_depth': None,
#  'voting__extraTrees11__max_features': 'sqrt',
#  'voting__extraTrees11__max_leaf_nodes': None,
#  'voting__extraTrees11__max_samples': None,
#  'voting__extraTrees11__min_impurity_decrease': 0.0,
#  'voting__extraTrees11__min_samples_leaf': 1,
#  'voting__extraTrees11__min_samples_split': 2,
#  'voting__extraTrees11__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees11__n_estimators': 100,
#  'voting__extraTrees11__n_jobs': None,
#  'voting__extraTrees11__oob_score': False,
#  'voting__extraTrees11__random_state': 951209,
#  'voting__extraTrees11__verbose': 0,
#  'voting__extraTrees11__warm_start': False,
#  'voting__extraTrees12__bootstrap': False,
#  'voting__extraTrees12__ccp_alpha': 0.0,
#  'voting__extraTrees12__class_weight': 'balanced',
#  'voting__extraTrees12__criterion': 'gini',
#  'voting__extraTrees12__max_depth': None,
#  'voting__extraTrees12__max_features': 'sqrt',
#  'voting__extraTrees12__max_leaf_nodes': None,
#  'voting__extraTrees12__max_samples': None,
#  'voting__extraTrees12__min_impurity_decrease': 0.0,
#  'voting__extraTrees12__min_samples_leaf': 1,
#  'voting__extraTrees12__min_samples_split': 2,
#  'voting__extraTrees12__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees12__n_estimators': 100,
#  'voting__extraTrees12__n_jobs': None,
#  'voting__extraTrees12__oob_score': False,
#  'voting__extraTrees12__random_state': 1327001,
#  'voting__extraTrees12__verbose': 0,
#  'voting__extraTrees12__warm_start': False,
#  'voting__extraTrees13__bootstrap': False,
#  'voting__extraTrees13__ccp_alpha': 0.0,
#  'voting__extraTrees13__class_weight': 'balanced',
#  'voting__extraTrees13__criterion': 'gini',
#  'voting__extraTrees13__max_depth': None,
#  'voting__extraTrees13__max_features': 'sqrt',
#  'voting__extraTrees13__max_leaf_nodes': None,
#  'voting__extraTrees13__max_samples': None,
#  'voting__extraTrees13__min_impurity_decrease': 0.0,
#  'voting__extraTrees13__min_samples_leaf': 1,
#  'voting__extraTrees13__min_samples_split': 2,
#  'voting__extraTrees13__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees13__n_estimators': 100,
#  'voting__extraTrees13__n_jobs': None,
#  'voting__extraTrees13__oob_score': False,
#  'voting__extraTrees13__random_state': 527903,
#  'voting__extraTrees13__verbose': 0,
#  'voting__extraTrees13__warm_start': False,
#  'voting__extraTrees14__bootstrap': False,
#  'voting__extraTrees14__ccp_alpha': 0.0,
#  'voting__extraTrees14__class_weight': 'balanced',
#  'voting__extraTrees14__criterion': 'gini',
#  'voting__extraTrees14__max_depth': None,
#  'voting__extraTrees14__max_features': 'sqrt',
#  'voting__extraTrees14__max_leaf_nodes': None,
#  'voting__extraTrees14__max_samples': None,
#  'voting__extraTrees14__min_impurity_decrease': 0.0,
#  'voting__extraTrees14__min_samples_leaf': 1,
#  'voting__extraTrees14__min_samples_split': 2,
#  'voting__extraTrees14__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees14__n_estimators': 100,
#  'voting__extraTrees14__n_jobs': None,
#  'voting__extraTrees14__oob_score': False,
#  'voting__extraTrees14__random_state': 1148093,
#  'voting__extraTrees14__verbose': 0,
#  'voting__extraTrees14__warm_start': False,
#  'voting__extraTrees15__bootstrap': False,
#  'voting__extraTrees15__ccp_alpha': 0.0,
#  'voting__extraTrees15__class_weight': 'balanced',
#  'voting__extraTrees15__criterion': 'gini',
#  'voting__extraTrees15__max_depth': None,
#  'voting__extraTrees15__max_features': 'sqrt',
#  'voting__extraTrees15__max_leaf_nodes': None,
#  'voting__extraTrees15__max_samples': None,
#  'voting__extraTrees15__min_impurity_decrease': 0.0,
#  'voting__extraTrees15__min_samples_leaf': 1,
#  'voting__extraTrees15__min_samples_split': 2,
#  'voting__extraTrees15__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees15__n_estimators': 100,
#  'voting__extraTrees15__n_jobs': None,
#  'voting__extraTrees15__oob_score': False,
#  'voting__extraTrees15__random_state': 1095286,
#  'voting__extraTrees15__verbose': 0,
#  'voting__extraTrees15__warm_start': False,
#  'voting__extraTrees16__bootstrap': False,
#  'voting__extraTrees16__ccp_alpha': 0.0,
#  'voting__extraTrees16__class_weight': 'balanced',
#  'voting__extraTrees16__criterion': 'gini',
#  'voting__extraTrees16__max_depth': None,
#  'voting__extraTrees16__max_features': 'sqrt',
#  'voting__extraTrees16__max_leaf_nodes': None,
#  'voting__extraTrees16__max_samples': None,
#  'voting__extraTrees16__min_impurity_decrease': 0.0,
#  'voting__extraTrees16__min_samples_leaf': 1,
#  'voting__extraTrees16__min_samples_split': 2,
#  'voting__extraTrees16__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees16__n_estimators': 100,
#  'voting__extraTrees16__n_jobs': None,
#  'voting__extraTrees16__oob_score': False,
#  'voting__extraTrees16__random_state': 1665788,
#  'voting__extraTrees16__verbose': 0,
#  'voting__extraTrees16__warm_start': False,
#  'voting__extraTrees17__bootstrap': False,
#  'voting__extraTrees17__ccp_alpha': 0.0,
#  'voting__extraTrees17__class_weight': 'balanced',
#  'voting__extraTrees17__criterion': 'gini',
#  'voting__extraTrees17__max_depth': None,
#  'voting__extraTrees17__max_features': 'sqrt',
#  'voting__extraTrees17__max_leaf_nodes': None,
#  'voting__extraTrees17__max_samples': None,
#  'voting__extraTrees17__min_impurity_decrease': 0.0,
#  'voting__extraTrees17__min_samples_leaf': 1,
#  'voting__extraTrees17__min_samples_split': 2,
#  'voting__extraTrees17__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees17__n_estimators': 100,
#  'voting__extraTrees17__n_jobs': None,
#  'voting__extraTrees17__oob_score': False,
#  'voting__extraTrees17__random_state': 97057,
#  'voting__extraTrees17__verbose': 0,
#  'voting__extraTrees17__warm_start': False,
#  'voting__extraTrees18__bootstrap': False,
#  'voting__extraTrees18__ccp_alpha': 0.0,
#  'voting__extraTrees18__class_weight': 'balanced',
#  'voting__extraTrees18__criterion': 'gini',
#  'voting__extraTrees18__max_depth': None,
#  'voting__extraTrees18__max_features': 'sqrt',
#  'voting__extraTrees18__max_leaf_nodes': None,
#  'voting__extraTrees18__max_samples': None,
#  'voting__extraTrees18__min_impurity_decrease': 0.0,
#  'voting__extraTrees18__min_samples_leaf': 1,
#  'voting__extraTrees18__min_samples_split': 2,
#  'voting__extraTrees18__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees18__n_estimators': 100,
#  'voting__extraTrees18__n_jobs': None,
#  'voting__extraTrees18__oob_score': False,
#  'voting__extraTrees18__random_state': 152878,
#  'voting__extraTrees18__verbose': 0,
#  'voting__extraTrees18__warm_start': False,
#  'voting__extraTrees19__bootstrap': False,
#  'voting__extraTrees19__ccp_alpha': 0.0,
#  'voting__extraTrees19__class_weight': 'balanced',
#  'voting__extraTrees19__criterion': 'gini',
#  'voting__extraTrees19__max_depth': None,
#  'voting__extraTrees19__max_features': 'sqrt',
#  'voting__extraTrees19__max_leaf_nodes': None,
#  'voting__extraTrees19__max_samples': None,
#  'voting__extraTrees19__min_impurity_decrease': 0.0,
#  'voting__extraTrees19__min_samples_leaf': 1,
#  'voting__extraTrees19__min_samples_split': 2,
#  'voting__extraTrees19__min_weight_fraction_leaf': 0.0,
#  'voting__extraTrees19__n_estimators': 100,
#  'voting__extraTrees19__n_jobs': None,
#  'voting__extraTrees19__oob_score': False,
#  'voting__extraTrees19__random_state': 4543,
#  'voting__extraTrees19__verbose': 0,
#  'voting__extraTrees19__warm_start': False,
#  'voting__extraTrees20__bootstrap': False,
#  'voting__extraTrees20__ccp_alpha': 0.0,
#  'voting__extraTrees20__class_weight': 'balanced',
#  'voting__extraTrees20__criterion': 'gini',
#  'voting__extraTrees20__max_depth': None,
#  'voting__extraTrees20__max_features': 'sqrt',
#  'voting__extraTrees20__max_leaf_nodes': None,
#  'voting__extraTrees20__max_samples': None,
#  'voting__extraTrees20__min_impurity_decrease': 0.0,
#  'voting__extraTrees20__min_samples_leaf': 1,
#  ...}

# %% [markdown]
# ### Evaludate Model

# %%
from sklearn.model_selection import StratifiedKFold
# Training Stats

cv = StratifiedKFold(n_splits=10)

plot_cross_validation_auroc(
    model, X_train, y_train,
    title='10-fold Cross Validation Training on PACE Cohort',
    cv = cv,
    # save_path = '/Users/muller/Documents/RugglesLab/publications/pace_press/Pace Edits/training_roc.pdf'
    )

export = plot_training_probas(
    model, X_train, y_train,
    title='10-fold Cross Validation Training on PACE Cohort',
    cv = cv,
    # save_path = '/Users/muller/Documents/RugglesLab/publications/pace_press/Pace Edits/pace_boxplot.pdf'
)
# Out:
# This function will be defunct in the future. Please use plot_cross_validation_auroc instead.

# %%
#### Metrics
print(classification_report(y_test, model.predict(X_test)))

# plot_roc_curve(y_test, model.predict_proba(X_test)[:,1])

# plot_confusion_matrix(y_test, model.predict(X_test), labels = ['normal', 'hyper'])

plot_roc_curve_ci(
    model, X_test, y_test,
    title='ROC Curve on Duke Cohort',
    bootstraps=80,
    # save_path = '/Users/muller/Documents/RugglesLab/publications/pace_press/Pace Edits/duke_roc.pdf'
    )

# get the auc
print(roc_auc_score(y_test, model.predict_proba(X_test)[:,1]))

# plot the confusion matrix
plot_confusion_matrix(y_test, model.predict(X_test), labels = ['normal', 'hyper'])

# plot the prc curve
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.metrics import auc

# predict probabilities
lr_probs = model.predict_proba(X_test)[:,1]
# calculate precision and recall for each threshold
lr_precision, lr_recall, _ = precision_recall_curve(y_test, lr_probs)
# calculate scores
lr_auc = auc(lr_recall, lr_precision)
# summarize scores
print('Logistic: PR AUC=%.3f' % (lr_auc))
# plot the precision-recall curves
no_skill = len(y_test[y_test==1]) / len(y_test)
plt.plot([0, 1], [no_skill, no_skill], linestyle='--', label='No Skill')
plt.plot(lr_recall, lr_precision, marker='.', label='Logistic')
# axis labels
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.legend()
# show the plot
plt.show()



# plot the prediction scores
preds = model.predict_proba(X_test)[:,1]
label = model.predict(X_test)
scores = pd.DataFrame({'preds':preds, 'label':y_test})

# plot the scores as a boxplot of the z-scores by the labels
fig, ax = plt.subplots(figsize=(8,6))
sns.boxplot(data=scores, x='label', y='preds', ax=ax)
ax.set_ylabel('Predictions Probability')
ax.set_xlabel('Predicted Label')
ax.set_xticklabels(['Control', 'Hyper'])
ax.set_title('Predictions on DUKE Data by Predicted Label')
# get a p value
p = kruskal(scores.loc[scores['label']==0, 'preds'], scores.loc[scores['label']==1, 'preds'])[1]
# add significance
ax.text(0.5, 0.9, f'p={p:.3f}', transform=ax.transAxes, ha='center', fontsize=14)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /Users/muller/Ruggles Lab Dropbox/Matthew Muller/projects/platelet-activity/models/model_testing_new_genesets.ipynb Cell 12 in 2
#       <a href='vscode-notebook-cell:/Users/muller/Ruggles%20Lab%20Dropbox/Matthew%20Muller/projects/platelet-activity/models/model_testing_new_genesets.ipynb#X14sZmlsZQ%3D%3D?line=0'>1</a> #### Metrics
# ----> <a href='vscode-notebook-cell:/Users/muller/Ruggles%20Lab%20Dropbox/Matthew%20Muller/projects/platelet-activity/models/model_testing_new_genesets.ipynb#X14sZmlsZQ%3D%3D?line=1'>2</a> print(classification_report(y_test, model.predict(X_test)))
#       <a href='vscode-notebook-cell:/Users/muller/Ruggles%20Lab%20Dropbox/Matthew%20Muller/projects/platelet-activity/models/model_testing_new_genesets.ipynb#X14sZmlsZQ%3D%3D?line=3'>4</a> # plot_roc_curve(y_test, model.predict_proba(X_test)[:,1])
#       <a href='vscode-notebook-cell:/Users/muller/Ruggles%20Lab%20Dropbox/Matthew%20Muller/projects/platelet-activity/models/model_testing_new_genesets.ipynb#X14sZmlsZQ%3D%3D?line=4'>5</a>
#       <a href='vscode-notebook-cell:/Users/muller/Ruggles%20Lab%20Dropbox/Matthew%20Muller/projects/platelet-activity/models/model_testing_new_genesets.ipynb#X14sZmlsZQ%3D%3D?line=5'>6</a> # plot_confusion_matrix(y_test, model.predict(X_test), labels = ['normal', 'hyper'])
#       <a href='vscode-notebook-cell:/Users/muller/Ruggles%20Lab%20Dropbox/Matthew%20Muller/projects/platelet-activity/models/model_testing_new_genesets.ipynb#X14sZmlsZQ%3D%3D?line=7'>8</a> plot_roc_curve_ci(
#       <a href='vscode-notebook-cell:/Users/muller/Ruggles%20Lab%20Dropbox/Matthew%20Muller/projects/platelet-activity/models/model_testing_new_genesets.ipynb#X14sZmlsZQ%3D%3D?line=8'>9</a>     model, X_test, y_test,
#      <a href='vscode-notebook-cell:/Users/muller/Ruggles%20Lab%20Dropbox/Matthew%20Muller/projects/platelet-activity/models/model_testing_new_genesets.ipynb#X14sZmlsZQ%3D%3D?line=9'>10</a>     title='ROC Curve on Duke Cohort',
#      <a href='vscode-notebook-cell:/Users/muller/Ruggles%20Lab%20Dropbox/Matthew%20Muller/projects/platelet-activity/models/model_testing_new_genesets.ipynb#X14sZmlsZQ%3D%3D?line=10'>11</a>     bootstraps=80,
#      <a href='vscode-notebook-cell:/Users/muller/Ruggles%20Lab%20Dropbox/Matthew%20Muller/projects/platelet-activity/models/model_testing_new_genesets.ipynb#X14sZmlsZQ%3D%3D?line=11'>12</a>     # save_path = '/Users/muller/Documents/RugglesLab/publications/pace_press/Pace Edits/duke_roc.pdf'
#      <a href='vscode-notebook-cell:/Users/muller/Ruggles%20Lab%20Dropbox/Matthew%20Muller/projects/platelet-activity/models/model_testing_new_genesets.ipynb#X14sZmlsZQ%3D%3D?line=12'>13</a>     )
#
# File /opt/homebrew/anaconda3/envs/tf/lib/python3.10/site-packages/sklearn/pipeline.py:480, in Pipeline.predict(self, X, **predict_params)
#     478 Xt = X
#     479 for _, name, transform in self._iter(with_final=False):
# --> 480     Xt = transform.transform(Xt)
#     481 return self.steps[-1][1].predict(Xt, **predict_params)
#
# File /opt/homebrew/anaconda3/envs/tf/lib/python3.10/site-packages/sklearn/utils/_set_output.py:140, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     138 @wraps(f)
#     139 def wrapped(self, X, *args, **kwargs):
# --> 140     data_to_wrap = f(self, X, *args, **kwargs)
#     141     if isinstance(data_to_wrap, tuple):
#     142         # only wrap the first output for cross decomposition
#     143         return (
#     144             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     145             *data_to_wrap[1:],
#     146         )
#
# File /opt/homebrew/anaconda3/envs/tf/lib/python3.10/site-packages/sklearn/preprocessing/_data.py:992, in StandardScaler.transform(self, X, copy)
#     989 check_is_fitted(self)
#     991 copy = copy if copy is not None else self.copy
# --> 992 X = self._validate_data(
#     993     X,
#     994     reset=False,
#     995     accept_sparse="csr",
#     996     copy=copy,
#     997     dtype=FLOAT_DTYPES,
#     998     force_all_finite="allow-nan",
#     999 )
#    1001 if sparse.issparse(X):
#    1002     if self.with_mean:
#
# File /opt/homebrew/anaconda3/envs/tf/lib/python3.10/site-packages/sklearn/base.py:548, in BaseEstimator._validate_data(self, X, y, reset, validate_separately, **check_params)
#     483 def _validate_data(
#     484     self,
#     485     X="no_validation",
#    (...)
#     489     **check_params,
#     490 ):
#     491     """Validate input data and set or check the `n_features_in_` attribute.
#     492
#     493     Parameters
#    (...)
#     546         validated.
#     547     """
# --> 548     self._check_feature_names(X, reset=reset)
#     550     if y is None and self._get_tags()["requires_y"]:
#     551         raise ValueError(
#     552             f"This {self.__class__.__name__} estimator "
#     553             "requires y to be passed, but the target y is None."
#     554         )
#
# File /opt/homebrew/anaconda3/envs/tf/lib/python3.10/site-packages/sklearn/base.py:481, in BaseEstimator._check_feature_names(self, X, reset)
#     476 if not missing_names and not unexpected_names:
#     477     message += (
#     478         "Feature names must be in the same order as they were in fit.\n"
#     479     )
# --> 481 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - AAMDC
# - ABCB7
# - AC002091.1
# - AC005229.4
# - AC005332.6
# - ...
# Feature names seen at fit time, yet now missing:
# - ABHD17A
# - ABHD18
# - AC104248.1
# - AC120114.1
# - AC131971.1
# - ...

# %%
### Save Model

# dump(model, filename='models/jobs/press_01_model_voting_a_ton_of_trees.joblib')

# %% [markdown]
# ### Model Disease Correlations

# %%
### Load in disease gene ratio data
sle_ratios = pd.read_csv('data/clean/model_validation/sle/sle_features_labels.csv', index_col=0)
male_ratios = pd.read_csv('data/clean/model_validation/male/male_features_labels.csv', index_col=0)
mace_ratios = pd.read_csv('data/clean/model_validation/mace/mace_features_labels.csv', index_col=0)
covid_ratios = pd.read_csv('data/clean/model_validation/covid/covid_features_labels.csv', index_col=0)
pad_ratios = pd.read_csv('data/clean/model_validation/pad/pad_features_labels.csv', index_col=0)
harp_ratios = pd.read_csv('data/clean/model_validation/harp/harp_features_labels.csv', index_col=0)


### Load in disease gene ratio data
# sle_ratios = pd.read_csv('data/clean/gene_ratios/disease_ratios/sle_gene_ratios_filtered_pace_60', index_col=0)
# male_ratios = pd.read_csv('data/clean/gene_ratios/disease_ratios/male_gene_ratios_filtered_pace_60', index_col=0)
# mace_ratios = pd.read_csv('data/clean/gene_ratios/disease_ratios/mace_gene_ratios_filtered_pace_60', index_col=0)
# covid_ratios = pd.read_csv('data/clean/gene_ratios/disease_ratios/covid_gene_ratios_filtered_pace_60', index_col=0)
# pad_ratios = pd.read_csv('data/clean/gene_ratios/disease_ratios/pad_gene_ratios_filtered_pace_60', index_col=0)
# harp_ratios = pd.read_csv('data/clean/gene_ratios/disease_ratios/harp_gene_ratios_filtered_pace_60', index_col=0)

disease_ratios = {'sle':sle_ratios, 'male':male_ratios, 'mace':mace_ratios, 
                  'covid':covid_ratios, 'pad':pad_ratios, 'harp':harp_ratios}

male_ratios
# Out:
#               AAMDC    AASDHPPT      ABCB7     ABHD17B  AC002091.1
# PACE_001  52.525035  226.514215   0.000000   85.353182    9.848444  \
# PACE_003  41.625585  322.774667  88.542559  121.701923   18.343478
# PACE_004  59.485647   71.202517  78.412899    2.703893   14.420763
# PACE_005  53.805840  138.460361  33.000915   81.784877    2.869645
# PACE_006  32.566297  264.460795  24.705467   81.415744   12.914221
# ...             ...         ...        ...         ...         ...
# PACE_285  84.103428   91.112047   0.000000    1.752155    0.000000
# PACE_289  51.254936  156.779803  46.732441   24.119970    4.522494
# PACE_293  64.681241  196.855951   1.406114   15.467253    8.436684
# PACE_295  33.123986   85.425016   0.000000   10.460206    5.230103
# PACE_300  20.536238   60.141840   0.000000   49.873721    5.867497
#
#            AC004053.1  AC005229.4   AC005332.6  AC006213.2  AC006378.2  ...
# PACE_001  1730.043349    9.848444   405.427616  101.767256    8.207037  ...  \
# PACE_003   927.051174   14.110368   937.281190   88.542559   22.576589  ...
# PACE_004   550.692886    8.111679  1277.138820   91.932364   23.433740  ...
# PACE_005   185.809501    4.304467  1017.289081   41.609850    4.304467  ...
# PACE_006   402.025328    3.930415   637.850240   21.898028   17.406125  ...
# ...               ...         ...          ...         ...         ...  ...
# PACE_285   413.508523   19.273702  3527.087529   12.265083   47.308178  ...
# PACE_289   901.483867   15.074981  1028.113708   76.882403   25.627468  ...
# PACE_293   828.201108   26.716165  1390.646683  104.052431   11.248911  ...
# PACE_295   523.010305    3.486735  1938.624864   27.893883    0.000000  ...
# PACE_300   595.550900    0.000000  1678.104014   98.280567   19.069364  ...
#
#           ZHX1-C8orf76        ZNF185       ZNF33A       ZNF44      ZNF451
# PACE_001      0.000000  33901.627452  1178.530479    9.848444  774.744270  \
# PACE_003      3.527592  28211.916896   905.885622  225.413128  564.414718
# PACE_004     11.716870  26524.289587   413.695638   18.025954  263.178924
# PACE_005      6.456701  36238.591914   489.274438   79.632643  281.942601
# PACE_006      3.368927  25653.820096   654.694877  211.119446  761.377576
# ...                ...           ...          ...         ...         ...
# PACE_285     42.051714  22802.542031   532.655047   21.025857  310.131392
# PACE_289      9.044989  47891.707295   767.316535   36.179955  438.681949
# PACE_293      7.030570  46967.017686   624.314588   26.716165  482.297080
# PACE_295     24.407148  51132.974151   470.709274   33.123986  198.743916
# PACE_300      1.466874  66041.607463  1026.811897    1.466874  378.453528
#
#              ZNF517       ZNF706      ZNF800    ZNF804A  cohort
# PACE_001  54.166443  1088.253074  160.857921   0.000000       1
# PACE_003  24.340385   900.241474  332.299165  14.110368       0
# PACE_004   0.000000   595.757770  122.576485  44.163587       1
# PACE_005  38.740205   401.032860  126.981782   2.869645       1
# PACE_006  19.090588   547.450690  326.224463   2.807439       0
# ...             ...          ...         ...        ...     ...
# PACE_285  17.521548   478.338249   71.838345   0.000000       0
# PACE_289  36.179955   413.054481   24.119970  10.552487       0
# PACE_293   8.436684   569.476144   67.493469   0.000000       0
# PACE_295   3.486735   367.850581   26.150515   0.000000       0
# PACE_300  14.668741   354.983542   32.271231   0.000000       0
#
# [129 rows x 403 columns]

# %%
### Prediction Results

for key in disease_ratios.keys():
    print(f'##################################### Current Disease: {key.upper()} #####################################')
    
    features = disease_ratios[key].drop('cohort', axis=1)
    labels = disease_ratios[key]['cohort']

    print(classification_report(labels, model.predict(features)))

    plot_roc_curve(labels, model.predict_proba(features)[:,1])


        # Predict and graph things
    preds = model.predict(features)
    conf_matrx = confusion_matrix(labels, preds)
    auc_score = roc_auc_score(labels, model.predict_proba(features)[:,1])


    sns.heatmap(conf_matrx, xticklabels=["Normal", "Hyper"], yticklabels=["Healthy", key],
                cmap="Blues", annot=True, fmt='g').set_title(f"{key} Platelet Activity Correlations \nAUC: {auc_score:.2f}")
    plt.show()


    # Weird results here, so I figure making a histogram of the model is helpful
    sns.set_theme(style="whitegrid", palette="colorblind")
    df = pd.DataFrame({'preds' : model.predict_proba(features)[:,1]})
    df['labels'] = labels.values
    df['labels'] = df['labels'].map({0:"Normal", 1:key})
    sns.boxplot(
        df, x='labels', y='preds', 
        order=["Normal", key], boxprops={'alpha': 0.75}
        ).set(ylabel="Prediction Value", xlabel=None)
    sns.stripplot(
        df, x='labels', y='preds',
        color = 'black', alpha = 0.75,
        order=["Normal", key]
        ).set(ylabel="Prediction Value", xlabel=None)

    # Significance Testing (kruskal-wallis for nonparametric analysis)    
    kruskal_wallis = kruskal(df.loc[df['labels'] == "Normal"]['preds'], df.loc[df['labels'] == key]['preds'])
    if kruskal_wallis[1] < 0.05:
        # statistical annotation
        x1, x2 = 0, 1
        y, h = df['preds'].max()+0.01, 0.01
        plt.plot([x1, x1, x2, x2], [y, y+h, y+h, y], lw=1.2, c='k')
        plt.text((x1+x2)*.5, y+h, f"p = {kruskal_wallis[1]:.4f}",
                 ha='center', va='bottom', color='k')

    plt.show()
# Out:
# ##################################### Current Disease: SLE #####################################
#               precision    recall  f1-score   support
#
#            0       0.26      1.00      0.41        18
#            1       0.00      0.00      0.00        51
#
#     accuracy                           0.26        69
#    macro avg       0.13      0.50      0.21        69
# weighted avg       0.07      0.26      0.11        69
# ##################################### Current Disease: MALE #####################################
#               precision    recall  f1-score   support
#
#            0       0.68      0.86      0.76        83
#            1       0.50      0.26      0.34        46
#
#     accuracy                           0.64       129
#    macro avg       0.59      0.56      0.55       129
# weighted avg       0.61      0.64      0.61       129
# ##################################### Current Disease: MACE #####################################
#               precision    recall  f1-score   support
#
#            0       0.68      0.79      0.73        90
#            1       0.21      0.13      0.16        39
#
#     accuracy                           0.59       129
#    macro avg       0.44      0.46      0.44       129
# weighted avg       0.53      0.59      0.56       129
# ##################################### Current Disease: COVID #####################################
#               precision    recall  f1-score   support
#
#            0       0.62      1.00      0.77        10
#            1       1.00      0.25      0.40         8
#
#     accuracy                           0.67        18
#    macro avg       0.81      0.62      0.58        18
# weighted avg       0.79      0.67      0.61        18
# ##################################### Current Disease: PAD #####################################
#               precision    recall  f1-score   support
#
#            0       0.10      1.00      0.19        12
#            1       1.00      0.19      0.32       129
#
#     accuracy                           0.26       141
#    macro avg       0.55      0.60      0.26       141
# weighted avg       0.92      0.26      0.31       141
# ##################################### Current Disease: HARP #####################################
#               precision    recall  f1-score   support
#
#            0       0.46      1.00      0.63        37
#            1       0.00      0.00      0.00        43
#
#     accuracy                           0.46        80
#    macro avg       0.23      0.50      0.32        80
# weighted avg       0.21      0.46      0.29        80
